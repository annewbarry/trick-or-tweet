# %%
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
from statistics import mean
from sklearn.metrics import confusion_matrix

import pandas as pd
import numpy as np

# %%
import json
#opens json file.  Each entry in the list is a dictionary that corresponds to the information about one tweet 
#example: the first entry might read {'created_at': 'Tue Sep 29 23:59:58 +0000 2020', 'full_text': 'RT @DarDar458: #PresidentialDebate #Debates2020 #TrumpIsANationalDisgrace'}
with open('~/datathon/data.jsonl', 'r') as json_file:
    json_list = list(json_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-0f79e73ce8b2> in <module>
#       2 #opens json file.  Each entry in the list is a dictionary that corresponds to the information about one tweet
#       3 #example: the first entry might read {'created_at': 'Tue Sep 29 23:59:58 +0000 2020', 'full_text': 'RT @DarDar458: #PresidentialDebate #Debates2020 #TrumpIsANationalDisgrace'}
# ----> 4 with open('~/datathon/data.jsonl', 'r') as json_file:
#       5     json_list = list(json_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/datathon/data.jsonl'

# %%
json_list_2 = []
for tweet in json_list:
    json_list_2.append(json.loads(tweet))
df = pd.DataFrame(json_list_2)

# %%
## make columns from information in the user column
df['user_description'] = df.user.apply(lambda x: x['description'])
df['user_followers'] = df.user.apply(lambda x: x['followers_count'])
df['hashtags'] = df.entities.apply(lambda x: x['hashtags'])

# %%
def determine_party(col):
    '''
    Looks through text to identify whether the user's description classifies them as a democrat or republican
    
    Input: string
    Output: string ('Dem', 'Rep', or 'unk')
    '''
    dem = ['biden', 'harris', 'democrat', 'liberal', 'progressive', 'socialist', 'cnn', 'msnbc']
    republican = ['trump', 'pence', 'fox', 'examiner', 'breitbart', 'maga', 'republican', 'conservative', 'make america great', 'keep america great']
    count = 0
    for i in dem:
        if col.lower().find(i)>=0:
            count +=1
    for i in republican:
        if col.lower().find(i)>=0:
            count -=1
    if count > 0:
        return 'Dem'
    elif count == 0:
        return 'unk'
    elif count < 0:
        return 'Rep'

def about(col):
    '''
    Returns 'Trump' if a string mentions Trump and not Biden and returns 'Biden' if a string mentions Biden and not Trump
    
    Input: string
    Output: string
    '''
    if col.lower().find('trump') >=0 and col.lower().find('biden') < 0:
        return 'Trump'
    if col.lower().find('biden') >=0 and col.lower().find('trump') < 0:
        return 'Biden'
    else:
        return 'no_candidate'

# %%
df['party'] = df.user_description.apply(determine_party)
df['about'] = df['full_text'].apply(about)
df['retweet'] = df['full_text'].apply(lambda x: x.find('RT')>=0)

# %%
## add columns to indicate Biden & Trump's top retweeted tweets
df['top_trump'] = df['full_text'].apply(
    lambda x: x.find('RT @realDonaldTrump: Tonight, @FLOTUS and I tested positive for COVID-19.') >=0)

df['top_biden'] = df['full_text'].apply(
    lambda x: x.find('RT @JoeBiden: I’m happy to report that Jill and I have tested negative for COVID.') >=0)

# %% [markdown]
# My "party" filter classified 24,443 people as Republican and 7810 people as Democrate.

# %%
df.party.value_counts()
# Out:
# unk    108084
# Rep     24443
# Dem      7810
# Name: party, dtype: int64

# %% [markdown]
# When looking at all of the tweets, the number of tweets that exclusively mention Trump far outweigh those that only mention Biden

# %%
df.about.value_counts()
# Out:
# Trump           68201
# no_candidate    48747
# Biden           23389
# Name: about, dtype: int64

# %% [markdown]
# When sorting by retweet count, it became clear that retweets are counted as separate tweets.  Trump's announcment that he had tested positive for covid is the secondmost retweeted tweet in that period, and it appears 3,120 times in our data set.

# %%
df[['full_text', 'retweet_count']].sort_values(by='retweet_count', ascending = False)
# Out:
#                                                 full_text  retweet_count
# 15183   RT @taylorswift13: After stoking the fires of ...         452964
# 120841  RT @realDonaldTrump: Tonight, @FLOTUS and I te...         412157
# 121963  RT @realDonaldTrump: Tonight, @FLOTUS and I te...         412157
# 122276  RT @realDonaldTrump: Tonight, @FLOTUS and I te...         412157
# 123039  RT @realDonaldTrump: Tonight, @FLOTUS and I te...         412157
# ...                                                   ...            ...
# 99992            @realDonaldTrump https://t.co/1PLb5cTKNJ              0
# 31282   Just another dead Black man in Trump's beady e...              0
# 100006  Is “Mother” going to let you stand in the same...              0
# 100008  @realhahnsolo @realDonaldTrump he cannot conde...              0
# 0       Biden a professional debater??  Hardly!! More ...              0
#
# [140337 rows x 2 columns]

# %%
df.groupby('full_text').count().sort_values(by = 'retweet_count', ascending = False)
# Out:
#                                                     created_at    id  id_str  \
# full_text
# RT @realDonaldTrump: Tonight, @FLOTUS and I tes...        3120  3120    3120
# RT @JoeBiden: I’m happy to report that Jill and...        1006  1006    1006
# RT @realDonaldTrump: https://t.co/HUSFkHqsyC               660   660     660
# RT @PeteButtigieg: Did the President of the Uni...         657   657     657
# RT @realDonaldTrump: https://t.co/B4H105KVSs               578   578     578
# ...                                                        ...   ...     ...
# Full Presidential Debate: President Trump and J...           1     1       1
# Full investigation.\n#BidenHarris2020\nhttps://...           1     1       1
# Full load in that one. https://t.co/QnUEUXnOQI               1     1       1
# Fun idea: Andy Cohen @Andy as the new debate mo...           1     1       1
# 🧿 https://t.co/1ztCC37fhC                                    1     1       1
#
#                                                     truncated  \
# full_text
# RT @realDonaldTrump: Tonight, @FLOTUS and I tes...       3120
# RT @JoeBiden: I’m happy to report that Jill and...       1006
# RT @realDonaldTrump: https://t.co/HUSFkHqsyC              660
# RT @PeteButtigieg: Did the President of the Uni...        657
# RT @realDonaldTrump: https://t.co/B4H105KVSs              578
# ...                                                       ...
# Full Presidential Debate: President Trump and J...          1
# Full investigation.\n#BidenHarris2020\nhttps://...          1
# Full load in that one. https://t.co/QnUEUXnOQI              1
# Fun idea: Andy Cohen @Andy as the new debate mo...          1
# 🧿 https://t.co/1ztCC37fhC                                   1
#
#                                                     display_text_range  \
# full_text
# RT @realDonaldTrump: Tonight, @FLOTUS and I tes...                3120
# RT @JoeBiden: I’m happy to report that Jill and...                1006
# RT @realDonaldTrump: https://t.co/HUSFkHqsyC                       660
# RT @PeteButtigieg: Did the President of the Uni...                 657
# RT @realDonaldTrump: https://t.co/B4H105KVSs                       578
# ...                                                                ...
# Full Presidential Debate: President Trump and J...                   1
# Full investigation.\n#BidenHarris2020\nhttps://...                   1
# Full load in that one. https://t.co/QnUEUXnOQI                       1
# Fun idea: Andy Cohen @Andy as the new debate mo...                   1
# 🧿 https://t.co/1ztCC37fhC                                            1
#
#                                                     entities  source  \
# full_text
# RT @realDonaldTrump: Tonight, @FLOTUS and I tes...      3120    3120
# RT @JoeBiden: I’m happy to report that Jill and...      1006    1006
# RT @realDonaldTrump: https://t.co/HUSFkHqsyC             660     660
# RT @PeteButtigieg: Did the President of the Uni...       657     657
# RT @realDonaldTrump: https://t.co/B4H105KVSs             578     578
# ...                                                      ...     ...
# Full Presidential Debate: President Trump and J...         1       1
# Full investigation.\n#BidenHarris2020\nhttps://...         1       1
# Full load in that one. https://t.co/QnUEUXnOQI             1       1
# Fun idea: Andy Cohen @Andy as the new debate mo...         1       1
# 🧿 https://t.co/1ztCC37fhC                                  1       1
#
#                                                     in_reply_to_status_id  \
# full_text
# RT @realDonaldTrump: Tonight, @FLOTUS and I tes...                      0
# RT @JoeBiden: I’m happy to report that Jill and...                      0
# RT @realDonaldTrump: https://t.co/HUSFkHqsyC                            0
# RT @PeteButtigieg: Did the President of the Uni...                      0
# RT @realDonaldTrump: https://t.co/B4H105KVSs                            0
# ...                                                                   ...
# Full Presidential Debate: President Trump and J...                      0
# Full investigation.\n#BidenHarris2020\nhttps://...                      1
# Full load in that one. https://t.co/QnUEUXnOQI                          0
# Fun idea: Andy Cohen @Andy as the new debate mo...                      0
# 🧿 https://t.co/1ztCC37fhC                                               0
#
#                                                     in_reply_to_status_id_str  \
# full_text
# RT @realDonaldTrump: Tonight, @FLOTUS and I tes...                          0
# RT @JoeBiden: I’m happy to report that Jill and...                          0
# RT @realDonaldTrump: https://t.co/HUSFkHqsyC                                0
# RT @PeteButtigieg: Did the President of the Uni...                          0
# RT @realDonaldTrump: https://t.co/B4H105KVSs                                0
# ...                                                                       ...
# Full Presidential Debate: President Trump and J...                          0
# Full investigation.\n#BidenHarris2020\nhttps://...                          1
# Full load in that one. https://t.co/QnUEUXnOQI                              0
# Fun idea: Andy Cohen @Andy as the new debate mo...                          0
# 🧿 https://t.co/1ztCC37fhC                                                   0
#
#                                                     in_reply_to_user_id  ...  \
# full_text                                                                ...
# RT @realDonaldTrump: Tonight, @FLOTUS and I tes...                    0  ...
# RT @JoeBiden: I’m happy to report that Jill and...                    0  ...
# RT @realDonaldTrump: https://t.co/HUSFkHqsyC                          0  ...
# RT @PeteButtigieg: Did the President of the Uni...                    0  ...
# RT @realDonaldTrump: https://t.co/B4H105KVSs                          0  ...
# ...                                                                 ...  ...
# Full Presidential Debate: President Trump and J...                    0  ...
# Full investigation.\n#BidenHarris2020\nhttps://...                    1  ...
# Full load in that one. https://t.co/QnUEUXnOQI                        0  ...
# Fun idea: Andy Cohen @Andy as the new debate mo...                    0  ...
# 🧿 https://t.co/1ztCC37fhC                                             0  ...
#
#                                                     extended_entities  \
# full_text
# RT @realDonaldTrump: Tonight, @FLOTUS and I tes...                  0
# RT @JoeBiden: I’m happy to report that Jill and...                  0
# RT @realDonaldTrump: https://t.co/HUSFkHqsyC                      660
# RT @PeteButtigieg: Did the President of the Uni...                  0
# RT @realDonaldTrump: https://t.co/B4H105KVSs                      578
# ...                                                               ...
# Full Presidential Debate: President Trump and J...                  0
# Full investigation.\n#BidenHarris2020\nhttps://...                  0
# Full load in that one. https://t.co/QnUEUXnOQI                      0
# Fun idea: Andy Cohen @Andy as the new debate mo...                  0
# 🧿 https://t.co/1ztCC37fhC                                           0
#
#                                                     withheld_in_countries  \
# full_text
# RT @realDonaldTrump: Tonight, @FLOTUS and I tes...                      1
# RT @JoeBiden: I’m happy to report that Jill and...                      0
# RT @realDonaldTrump: https://t.co/HUSFkHqsyC                            0
# RT @PeteButtigieg: Did the President of the Uni...                      0
# RT @realDonaldTrump: https://t.co/B4H105KVSs                            0
# ...                                                                   ...
# Full Presidential Debate: President Trump and J...                      0
# Full investigation.\n#BidenHarris2020\nhttps://...                      0
# Full load in that one. https://t.co/QnUEUXnOQI                          0
# Fun idea: Andy Cohen @Andy as the new debate mo...                      0
# 🧿 https://t.co/1ztCC37fhC                                               0
#
#                                                     user_description  \
# full_text
# RT @realDonaldTrump: Tonight, @FLOTUS and I tes...              3120
# RT @JoeBiden: I’m happy to report that Jill and...              1006
# RT @realDonaldTrump: https://t.co/HUSFkHqsyC                     660
# RT @PeteButtigieg: Did the President of the Uni...               657
# RT @realDonaldTrump: https://t.co/B4H105KVSs                     578
# ...                                                              ...
# Full Presidential Debate: President Trump and J...                 1
# Full investigation.\n#BidenHarris2020\nhttps://...                 1
# Full load in that one. https://t.co/QnUEUXnOQI                     1
# Fun idea: Andy Cohen @Andy as the new debate mo...                 1
# 🧿 https://t.co/1ztCC37fhC                                          1
#
#                                                     top_trump  top_biden  \
# full_text
# RT @realDonaldTrump: Tonight, @FLOTUS and I tes...       3120       3120
# RT @JoeBiden: I’m happy to report that Jill and...       1006       1006
# RT @realDonaldTrump: https://t.co/HUSFkHqsyC              660        660
# RT @PeteButtigieg: Did the President of the Uni...        657        657
# RT @realDonaldTrump: https://t.co/B4H105KVSs              578        578
# ...                                                       ...        ...
# Full Presidential Debate: President Trump and J...          1          1
# Full investigation.\n#BidenHarris2020\nhttps://...          1          1
# Full load in that one. https://t.co/QnUEUXnOQI              1          1
# Fun idea: Andy Cohen @Andy as the new debate mo...          1          1
# 🧿 https://t.co/1ztCC37fhC                                   1          1
#
#                                                     user_followers  hashtags  \
# full_text
# RT @realDonaldTrump: Tonight, @FLOTUS and I tes...            3120      3120
# RT @JoeBiden: I’m happy to report that Jill and...            1006      1006
# RT @realDonaldTrump: https://t.co/HUSFkHqsyC                   660       660
# RT @PeteButtigieg: Did the President of the Uni...             657       657
# RT @realDonaldTrump: https://t.co/B4H105KVSs                   578       578
# ...                                                            ...       ...
# Full Presidential Debate: President Trump and J...               1         1
# Full investigation.\n#BidenHarris2020\nhttps://...               1         1
# Full load in that one. https://t.co/QnUEUXnOQI                   1         1
# Fun idea: Andy Cohen @Andy as the new debate mo...               1         1
# 🧿 https://t.co/1ztCC37fhC                                        1         1
#
#                                                     party  about  retweet
# full_text
# RT @realDonaldTrump: Tonight, @FLOTUS and I tes...   3120   3120     3120
# RT @JoeBiden: I’m happy to report that Jill and...   1006   1006     1006
# RT @realDonaldTrump: https://t.co/HUSFkHqsyC          660    660      660
# RT @PeteButtigieg: Did the President of the Uni...    657    657      657
# RT @realDonaldTrump: https://t.co/B4H105KVSs          578    578      578
# ...                                                   ...    ...      ...
# Full Presidential Debate: President Trump and J...      1      1        1
# Full investigation.\n#BidenHarris2020\nhttps://...      1      1        1
# Full load in that one. https://t.co/QnUEUXnOQI          1      1        1
# Fun idea: Andy Cohen @Andy as the new debate mo...      1      1        1
# 🧿 https://t.co/1ztCC37fhC                               1      1        1
#
# [72746 rows x 39 columns]

# %%
b_t_ratio = df.about.value_counts().loc['Biden']/df.about.value_counts().loc['Trump']
print(f'Biden/Trump ratio with all retweets: {b_t_ratio:.4f}')
# Out:
# Biden/Trump ratio with all retweets: 0.3429

# %%
no_rt = df.drop_duplicates(subset=['full_text'])

# %%
no_rt.about.value_counts()
# Out:
# Trump           34733
# no_candidate    27123
# Biden           10890
# Name: about, dtype: int64

# %% [markdown]
# At this point I decided to take out all but the first instance of a tweet.  When taking out duplicate retweets, the ratio of Biden to Trump tweets is roughly the same as before.

# %%
b_t_ratio = no_rt.about.value_counts().loc['Biden']/no_rt.about.value_counts().loc['Trump']
print(f'Biden/Trump ratio without duplicate retweets: {b_t_ratio:.4f}')
# Out:
# Biden/Trump ratio without duplicate retweets: 0.3135

# %%
df_biden = no_rt[no_rt['about'] == 'Biden']
df_trump = no_rt[no_rt['about'] == 'Trump']
print(f'The mean number of retweets for a Biden-focused tweet is {df_biden.retweet_count.mean():.0f} and the mean number of re-tweets for a Trump-focused tweet is {df_trump.retweet_count.mean():.0f}')
# Out:
# The mean number of retweets for a Biden-focused tweet is 821 and the mean number of re-tweets for a Trump-focused tweet is 773

# %%
df_trump.sort_values(by = 'retweet_count', ascending = False).iloc[2, 2]
# Out:
# '1311908042993274880'

# %%
###THIS HISTOGRAM IS ALL FUCKED UP

trump_retweet_graph = df_trump[df_trump['top_trump']==False].retweet_count
biden_retweet_graph = df_biden[df_biden['top_trump']==False].retweet_count

fig ,ax = plt.subplots()
ax.hist([biden_retweet_graph, trump_retweet_graph], bins = np.arange(14000,100), density = True, align = ('mid'), color = ['#F6AEA8', '#A8C7F6'], label = ['Biden', 'Trump'])
ax.spines["bottom"].set_visible(True)      
ax.spines["left"].set_visible(True)
ax.axvline(df_biden.retweet_count.mean(), color = 'red', linestyle="--")
ax.axvline(df_trump.retweet_count.mean(), color = 'blue', linestyle="--")
ax.set_title('Retweets by Candidate Focus')
ax.set_xlim([0,15000])
# ax.set_yticklabels([])
# ax.set_xticklabels(labels[i], rotation = '45')
# ax.set_xticks(bins[i])
ax.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Finally,I wanted to look at the text of tweets that are about one candidate or the other

# %%
df_final = no_rt[no_rt['about'] != 'no_candidate']

# %%
df_final.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Tue Sep 29 23:59:56 +0000 2020  1311093385688735744  1311093385688735744
# 1  Tue Sep 29 23:59:58 +0000 2020  1311093394400333824  1311093394400333824
# 3  Wed Sep 30 00:00:02 +0000 2020  1311093410737070086  1311093410737070086
# 4  Wed Sep 30 00:00:04 +0000 2020  1311093419100561408  1311093419100561408
# 7  Wed Sep 30 00:00:10 +0000 2020  1311093442592743424  1311093442592743424
#
#                                            full_text  truncated  \
# 0  Biden a professional debater??  Hardly!! More ...      False
# 1  RT @DarDar458: #PresidentialDebate #Debates202...      False
# 3  RT @abbydphillip: Very reminiscent of pre-2018...      False
# 4  RT @RudyGiuliani: Why was Corrupt Biden’s son ...      False
# 7  RT @realDonaldTrump: Thank you #Truckers4Trump...      False
#
#   display_text_range                                           entities  \
# 0            [0, 71]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1            [0, 73]  {'hashtags': [{'text': 'PresidentialDebate', '...
# 3           [0, 108]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4           [0, 110]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 7            [0, 72]  {'hashtags': [{'text': 'Truckers4Trump', 'indi...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 1  <a href="http://twitter.com/download/iphone" r...                    NaN
# 3  <a href="http://twitter.com/download/iphone" r...                    NaN
# 4  <a href="http://twitter.com/download/iphone" r...                    NaN
# 7  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
#
#   in_reply_to_status_id_str  ...  \
# 0                      None  ...
# 1                      None  ...
# 3                      None  ...
# 4                      None  ...
# 7                      None  ...
#
#                                    extended_entities withheld_in_countries  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
# 7  {'media': [{'id': 1310422596324913152, 'id_str...                   NaN
#
#                                     user_description top_trump top_biden  \
# 0  Conservative/#MAGA/ #WWG1WGA /MbrNRA/#Trump202...     False     False
# 1  Canadian 🇨🇦 Windmill Cancer Survivor. I follow...     False     False
# 3  Politics reporter covering elections & voting ...     False     False
# 4  wife, mother, grandmother, southerner, conserv...     False     False
# 7                one of the broncos biggest fan ever     False     False
#
#   user_followers                                           hashtags party  \
# 0           4065                                                 []   Rep
# 1          31031  [{'text': 'PresidentialDebate', 'indices': [15...   unk
# 3          21737                                                 []   unk
# 4            893                                                 []   Rep
# 7             61  [{'text': 'Truckers4Trump', 'indices': [31, 46]}]   unk
#
#    about  retweet
# 0  Biden    False
# 1  Trump     True
# 3  Trump     True
# 4  Biden     True
# 7  Trump     True
#
# [5 rows x 40 columns]

# %%
l = topic_data.full_text.tolist()

# %%
df_final_b = df_final[df_final['about']=='Biden']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aaea501bac36> in <module>
# ----> 1 df_final_b = df_final[df_final['about']=='Biden']
#
# NameError: name 'df_final' is not defined

# %%
y = topic_data['about']
tfidf = TfidfVectorizer(stop_words = sw, ngram_range = (1,3), max_features = 1500)
X = tfidf.fit_transform(topic_data.full_text)
labels = tfidf.get_feature_names()
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, random_state = 5)
# Out:
# /Users/annebarry/opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:386: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['first', 'lady'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
clf = MultinomialNB()
clf = clf.fit(X_train, y_train)
cvs = np.mean(cross_val_score(clf, X_train, y_train))

# %%
tb, ft, fb, tt = confusion_matrix(y_test, clf.predict(X_test)).ravel()
print(f'True Biden: {tb}, False Trump: {ft}, False Biden: {fb}, True Trump: {tt}')
print(f'Recall for Biden: {tb/(tb + ft)}')
print(f'Recall for Trump: {tt/(fb + tt)}')
print(f'Cross-validation score: {cvs}')
# Out:
# True Biden: 1419, False Trump: 2503, False Biden: 227, True Trump: 11215
# Recall for Biden: 0.36180520142784295
# Recall for Trump: 0.9801608110470198
# Cross-validation score: 0.8252944193864042

# %%
def get_top_features(feature_logs, labels, num_features):
    zero_all = np.array(labels)[np.argsort(feature_logs[0])[-1*num_features:]]
    one_all = np.array(labels)[np.argsort(feature_logs[1])[-1*num_features:]]
    zero_unique = [x for x in zero_all if x not in one_all]
    one_unique = [x for x in one_all if x not in zero_all]
    return zero_all, one_all, zero_unique, one_unique

zero, one, zero_unique, one_unique = get_top_features(clf.feature_log_prob_, labels, 50)

print(" ")
print(f'Biden unique: {zero_unique}')
print(f'Trump unique: {one_unique}')
# Out:
#
# Biden unique: ['violent', 'become', 'country', 'put', 'harris', 'racist', 'family', 'way', 'president united states', 'president united', 'back', 'united states', 'last night', 'united', 'years', 'idea', 'man', 'enough', 'chris wallace', 'states', 'american', 'son', 'antifa']
# Trump unique: ['still', 'supporters', 'virus', 'condemn white', 'voting', 'never', 'proud boys', 'see', 'election', 'news', 'white supremacists', 'boys', 'supremacists', 'right', 'going', 'condemn', 'hope', 'stand', 'new', 'says', 'first', 'coronavirus', 'get']

# %%
new_sw = ['jill', 'first lady', 'donald', 'don','flotus','hunter','joebiden', 'trump','realdonaldtrump','19','quarantine', 'amp','say','melania','rt','biden','thank', 'concern', 'husfkhqsyc', 'joe', 'b4h105kvss', 'covid', 'tested', 'test', 'co', 'realjameswoods', 'messages','begin', 'https','happy', 'report', 'everyone', 'hop', 'must', 'que', 'positive','negative','recovery','tonight','process','immediately','joseph']

# %%
sw = stopwords.words('english')

for i in new_sw:
    sw.append(i)

# %%
topic_data[topic_data['full_text'].apply(lambda x: x.lower().find('happy to report')>=0)].iloc[0,2]
# Out:
# 'RT @JoeBiden: I’m happy to report that Jill and I have tested negative for COVID. Thank you to everyone for your messages of concern. I hop…'
